# %% [markdown]
# ## Exemples de random numbers

# %%
import numpy as np

# %%
a=np.random.uniform(-1.0,1.0) #genera nombres aleatoris distribuits uniformement entre un interval que donem
print(a)
# Out:
# 0.9012261953229801

# %%
b=np.random.randint(1,6) #genera un valor aleatori enter en un interval donat
print(b)
# Out:
# 4
